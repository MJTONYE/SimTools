# %% [markdown]
# Die MC-Schätzer konvergieren für alle drei Funktionen wie erwartet gegen den wahren Wert.
# Der Standardfehler skaliert ungefähr proportional zu
# 1
# /
# 𝑁
# 1/
# N
# 	​
#
# .
# Die Laufzeit steigt linear mit N.
# Die Konfidenzintervalle werden für große N sehr eng.
# g₂ und g₃ sind glatter, daher ist die Varianz niedriger als bei g₁.
