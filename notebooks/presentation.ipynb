# %%
import numpy as np
import sys
sys.path.append('../') # um Funktionen aus dem Parent-Verzeichnis zu laden

# %%
from src.integration import mc_expectation

# %%
rng = np.random.default_rng(42)
mu, se = mc_expectation(
    lambda u: (u[:,0]**2+u[:,1]**2<=1).astype(float)*4,
    sampler=lambda N, r: r.random((N, 2)), N=200_000, rng=rng
)

# %%
mu

# %%
np.pi

# %%
se
